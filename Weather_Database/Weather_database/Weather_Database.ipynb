# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city= citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        country= city_weather['sys']['country']
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | harbour breton
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | anadyr
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | clyde river
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | port hardy
# Processing Record 10 of Set 1 | husavik
# Processing Record 11 of Set 1 | faanui
# Processing Record 12 of Set 1 | ortona
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | lompoc
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | okitipupa
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 1 | kelo
# Processing Record 24 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | irece
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 1 | waynesville
# Processing Record 32 of Set 1 | najran
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | noumea
# Processing Record 35 of Set 1 | kieta
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | namtsy
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | sompeta
# Processing Record 41 of Set 1 | lagoa
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | moose jaw
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | mecca
# Processing Record 47 of Set 1 | ambo
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | centralia
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | ponta delgada
# Processing Record 4 of Set 2 | sao filipe
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 2 | namibe
# Processing Record 8 of Set 2 | adrar
# Processing Record 9 of Set 2 | sirari
# Processing Record 10 of Set 2 | nikolskoye
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | paamiut
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | visakhapatnam
# Processing Record 16 of Set 2 | sinnamary
# Processing Record 17 of Set 2 | terrace
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | yangjiang
# Processing Record 20 of Set 2 | mareeba
# Processing Record 21 of Set 2 | san patricio
# Processing Record 22 of Set 2 | dunedin
# Processing Record 23 of Set 2 | hamilton
# Processing Record 24 of Set 2 | north bend
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | moanda
# Processing Record 27 of Set 2 | manggar
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | lebu
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 2 | vostok
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | trairi
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | dongli
# Processing Record 38 of Set 2 | maceio
# Processing Record 39 of Set 2 | nanakuli
# Processing Record 40 of Set 2 | peniche
# Processing Record 41 of Set 2 | powell
# Processing Record 42 of Set 2 | salaspils
# Processing Record 43 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 2 | lithakia
# Processing Record 45 of Set 2 | port lincoln
# Processing Record 46 of Set 2 | lata
# Processing Record 47 of Set 2 | tanout
# Processing Record 48 of Set 2 | altay
# Processing Record 49 of Set 2 | le port
# Processing Record 50 of Set 2 | daru
# Processing Record 1 of Set 3 | hambantota
# Processing Record 2 of Set 3 | carutapera
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | peleduy
# Processing Record 5 of Set 3 | kupang
# Processing Record 6 of Set 3 | paka
# Processing Record 7 of Set 3 | vila do maio
# Processing Record 8 of Set 3 | vila franca do campo
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | awbari
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | rio claro
# Processing Record 14 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 3 | yoshida
# Processing Record 16 of Set 3 | jinchang
# Processing Record 17 of Set 3 | sorong
# Processing Record 18 of Set 3 | samarai
# Processing Record 19 of Set 3 | acton
# Processing Record 20 of Set 3 | bartica
# Processing Record 21 of Set 3 | chebsara
# Processing Record 22 of Set 3 | deputatskiy
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | wagar
# Processing Record 25 of Set 3 | cape town
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | kulhudhuffushi
# Processing Record 28 of Set 3 | namatanai
# Processing Record 29 of Set 3 | phitsanulok
# Processing Record 30 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | new norfolk
# Processing Record 33 of Set 3 | hasaki
# Processing Record 34 of Set 3 | odweyne
# Processing Record 35 of Set 3 | manikpur
# Processing Record 36 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 3 | smithers
# Processing Record 38 of Set 3 | avarua
# Processing Record 39 of Set 3 | luderitz
# Processing Record 40 of Set 3 | calvinia
# Processing Record 41 of Set 3 | rovaniemi
# Processing Record 42 of Set 3 | cherskiy
# Processing Record 43 of Set 3 | purranque
# Processing Record 44 of Set 3 | poum
# Processing Record 45 of Set 3 | ostersund
# Processing Record 46 of Set 3 | barreirinha
# Processing Record 47 of Set 3 | nelson bay
# Processing Record 48 of Set 3 | barra patuca
# Processing Record 49 of Set 3 | teguise
# Processing Record 50 of Set 3 | mount isa
# Processing Record 1 of Set 4 | hobart
# Processing Record 2 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 4 | martinsburg
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | ilhabela
# Processing Record 6 of Set 4 | te anau
# Processing Record 7 of Set 4 | san francisco
# Processing Record 8 of Set 4 | playas
# Processing Record 9 of Set 4 | kuldur
# Processing Record 10 of Set 4 | plunge
# Processing Record 11 of Set 4 | tazovskiy
# Processing Record 12 of Set 4 | zhigansk
# Processing Record 13 of Set 4 | devils lake
# Processing Record 14 of Set 4 | touros
# Processing Record 15 of Set 4 | victoria
# Processing Record 16 of Set 4 | gubkinskiy
# Processing Record 17 of Set 4 | pangody
# Processing Record 18 of Set 4 | puerto penasco
# Processing Record 19 of Set 4 | tilichiki
# Processing Record 20 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 4 | luau
# Processing Record 22 of Set 4 | mar del plata
# Processing Record 23 of Set 4 | aksha
# Processing Record 24 of Set 4 | longyearbyen
# Processing Record 25 of Set 4 | sao joao da barra
# Processing Record 26 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 4 | solnechnyy
# Processing Record 28 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 4 | xining
# Processing Record 31 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 32 of Set 4 | sakaiminato
# Processing Record 33 of Set 4 | nioro
# Processing Record 34 of Set 4 | skibbereen
# Processing Record 35 of Set 4 | oistins
# Processing Record 36 of Set 4 | caloundra
# Processing Record 37 of Set 4 | xuddur
# Processing Record 38 of Set 4 | san carlos de bariloche
# Processing Record 39 of Set 4 | nyurba
# Processing Record 40 of Set 4 | bayan
# Processing Record 41 of Set 4 | la romana
# Processing Record 42 of Set 4 | cabedelo
# Processing Record 43 of Set 4 | cabo san lucas
# Processing Record 44 of Set 4 | oga
# Processing Record 45 of Set 4 | college
# Processing Record 46 of Set 4 | gat
# Processing Record 47 of Set 4 | dhamtari
# Processing Record 48 of Set 4 | esperance
# Processing Record 49 of Set 4 | iralaya
# Processing Record 50 of Set 4 | puerto ayora
# Processing Record 1 of Set 5 | hirara
# Processing Record 2 of Set 5 | ponta do sol
# Processing Record 3 of Set 5 | hammerfest
# Processing Record 4 of Set 5 | krasnoselkup
# Processing Record 5 of Set 5 | walvis bay
# Processing Record 6 of Set 5 | rute
# Processing Record 7 of Set 5 | pangai
# Processing Record 8 of Set 5 | vila
# Processing Record 9 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 10 of Set 5 | oktyabrskoye
# Processing Record 11 of Set 5 | tommot
# Processing Record 12 of Set 5 | hereford
# Processing Record 13 of Set 5 | airai
# Processing Record 14 of Set 5 | srednekolymsk
# Processing Record 15 of Set 5 | richard toll
# City not found. Skipping...
# Processing Record 16 of Set 5 | panaba
# Processing Record 17 of Set 5 | lasa
# Processing Record 18 of Set 5 | riyadh
# Processing Record 19 of Set 5 | inhambane
# Processing Record 20 of Set 5 | ulaangom
# Processing Record 21 of Set 5 | carnarvon
# Processing Record 22 of Set 5 | saint-philippe
# Processing Record 23 of Set 5 | half moon bay
# Processing Record 24 of Set 5 | lavrentiya
# Processing Record 25 of Set 5 | vila velha
# Processing Record 26 of Set 5 | astoria
# Processing Record 27 of Set 5 | angatuba
# Processing Record 28 of Set 5 | san vicente
# Processing Record 29 of Set 5 | ruston
# Processing Record 30 of Set 5 | kashary
# Processing Record 31 of Set 5 | manzil salim
# Processing Record 32 of Set 5 | saint-georges
# Processing Record 33 of Set 5 | santa maria
# Processing Record 34 of Set 5 | labuhan
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | capreol
# Processing Record 37 of Set 5 | vardo
# Processing Record 38 of Set 5 | palauig
# Processing Record 39 of Set 5 | puerto madero
# Processing Record 40 of Set 5 | siero
# Processing Record 41 of Set 5 | saint-pierre
# Processing Record 42 of Set 5 | chimbote
# Processing Record 43 of Set 5 | narsaq
# Processing Record 44 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 5 | bengkulu
# Processing Record 47 of Set 5 | bainbridge
# Processing Record 48 of Set 5 | muqui
# Processing Record 49 of Set 5 | nieuwpoort
# Processing Record 50 of Set 5 | talara
# Processing Record 1 of Set 6 | solton
# Processing Record 2 of Set 6 | yerbogachen
# Processing Record 3 of Set 6 | xiongzhou
# Processing Record 4 of Set 6 | kloulklubed
# Processing Record 5 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 6 | mahebourg
# Processing Record 7 of Set 6 | jaque
# Processing Record 8 of Set 6 | ayan
# Processing Record 9 of Set 6 | port elizabeth
# Processing Record 10 of Set 6 | karaman
# Processing Record 11 of Set 6 | matagami
# Processing Record 12 of Set 6 | ylojarvi
# Processing Record 13 of Set 6 | rocha
# Processing Record 14 of Set 6 | port hedland
# Processing Record 15 of Set 6 | turayf
# Processing Record 16 of Set 6 | kasongo-lunda
# Processing Record 17 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 18 of Set 6 | santa rosalia
# Processing Record 19 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 6 | norfolk
# Processing Record 21 of Set 6 | turukhansk
# Processing Record 22 of Set 6 | marsa matruh
# Processing Record 23 of Set 6 | torbay
# Processing Record 24 of Set 6 | camana
# Processing Record 25 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 6 | aquiraz
# Processing Record 27 of Set 6 | faya
# Processing Record 28 of Set 6 | huejuquilla el alto
# Processing Record 29 of Set 6 | coquimbo
# Processing Record 30 of Set 6 | saldanha
# Processing Record 31 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 32 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 6 | altamont
# Processing Record 34 of Set 6 | klaksvik
# Processing Record 35 of Set 6 | ilulissat
# Processing Record 36 of Set 6 | la ronge
# Processing Record 37 of Set 6 | egvekinot
# Processing Record 38 of Set 6 | tecoanapa
# Processing Record 39 of Set 6 | hacari
# Processing Record 40 of Set 6 | padang
# Processing Record 41 of Set 6 | tessalit
# Processing Record 42 of Set 6 | celestun
# Processing Record 43 of Set 6 | beloha
# Processing Record 44 of Set 6 | vilyuysk
# Processing Record 45 of Set 6 | shitanjing
# Processing Record 46 of Set 6 | leningradskiy
# Processing Record 47 of Set 6 | teguldet
# Processing Record 48 of Set 6 | alihe
# Processing Record 49 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 50 of Set 6 | pacific grove
# Processing Record 1 of Set 7 | eregli
# Processing Record 2 of Set 7 | amasya
# Processing Record 3 of Set 7 | goderich
# Processing Record 4 of Set 7 | omsukchan
# Processing Record 5 of Set 7 | naze
# Processing Record 6 of Set 7 | hervey bay
# Processing Record 7 of Set 7 | bay roberts
# Processing Record 8 of Set 7 | singaraja
# Processing Record 9 of Set 7 | pevek
# Processing Record 10 of Set 7 | burnie
# Processing Record 11 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 7 | izhevskoye
# Processing Record 13 of Set 7 | uglegorsk
# Processing Record 14 of Set 7 | sitka
# Processing Record 15 of Set 7 | ugoofaaru
# Processing Record 16 of Set 7 | beinamar
# Processing Record 17 of Set 7 | sur
# Processing Record 18 of Set 7 | verkhnyaya toyma
# Processing Record 19 of Set 7 | mao
# Processing Record 20 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 7 | bathsheba
# Processing Record 22 of Set 7 | roald
# Processing Record 23 of Set 7 | stavrovo
# Processing Record 24 of Set 7 | plouzane
# Processing Record 25 of Set 7 | denpasar
# Processing Record 26 of Set 7 | kaeo
# Processing Record 27 of Set 7 | oyo
# Processing Record 28 of Set 7 | rio grande
# Processing Record 29 of Set 7 | evansville
# Processing Record 30 of Set 7 | virginia beach
# Processing Record 31 of Set 7 | cidreira
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | mpulungu
# Processing Record 34 of Set 7 | ornskoldsvik
# Processing Record 35 of Set 7 | pocatello
# Processing Record 36 of Set 7 | chabahar
# Processing Record 37 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 7 | moyale
# Processing Record 39 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 40 of Set 7 | guerrero negro
# Processing Record 41 of Set 7 | san quintin
# Processing Record 42 of Set 7 | ulladulla
# Processing Record 43 of Set 7 | lashio
# Processing Record 44 of Set 7 | kokopo
# Processing Record 45 of Set 7 | thinadhoo
# Processing Record 46 of Set 7 | copiapo
# Processing Record 47 of Set 7 | dekoa
# City not found. Skipping...
# Processing Record 48 of Set 7 | komsomolskiy
# Processing Record 49 of Set 7 | muros
# Processing Record 50 of Set 7 | johnstown
# Processing Record 1 of Set 8 | aqtobe
# Processing Record 2 of Set 8 | changde
# Processing Record 3 of Set 8 | calamar
# Processing Record 4 of Set 8 | acapulco
# Processing Record 5 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 8 | grindavik
# Processing Record 7 of Set 8 | bilma
# Processing Record 8 of Set 8 | biloela
# Processing Record 9 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 8 | sungairaya
# Processing Record 12 of Set 8 | fallon
# Processing Record 13 of Set 8 | aksu
# Processing Record 14 of Set 8 | shenjiamen
# Processing Record 15 of Set 8 | nabire
# Processing Record 16 of Set 8 | yefira
# City not found. Skipping...
# Processing Record 17 of Set 8 | rio bueno
# Processing Record 18 of Set 8 | bubaque
# Processing Record 19 of Set 8 | san jose de guanipa
# Processing Record 20 of Set 8 | flic en flac
# Processing Record 21 of Set 8 | kamenka
# Processing Record 22 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 23 of Set 8 | jiuquan
# Processing Record 24 of Set 8 | aasiaat
# Processing Record 25 of Set 8 | mumbwa
# Processing Record 26 of Set 8 | constitucion
# Processing Record 27 of Set 8 | nishihara
# Processing Record 28 of Set 8 | corumba
# Processing Record 29 of Set 8 | doha
# Processing Record 30 of Set 8 | khatanga
# Processing Record 31 of Set 8 | norsup
# Processing Record 32 of Set 8 | klyuchi
# Processing Record 33 of Set 8 | ibra
# Processing Record 34 of Set 8 | novyy urengoy
# Processing Record 35 of Set 8 | carman
# Processing Record 36 of Set 8 | astakos
# Processing Record 37 of Set 8 | salalah
# Processing Record 38 of Set 8 | kazanskoye
# Processing Record 39 of Set 8 | jhalida
# Processing Record 40 of Set 8 | lorengau
# Processing Record 41 of Set 8 | bontang
# Processing Record 42 of Set 8 | olafsvik
# Processing Record 43 of Set 8 | kalmunai
# Processing Record 44 of Set 8 | atka
# City not found. Skipping...
# Processing Record 45 of Set 8 | sambava
# Processing Record 46 of Set 8 | itarema
# Processing Record 47 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 8 | mendi
# Processing Record 49 of Set 8 | yellamanchili
# City not found. Skipping...
# Processing Record 50 of Set 8 | lander
# Processing Record 1 of Set 9 | riviere-au-renard
# Processing Record 2 of Set 9 | chunoyar
# Processing Record 3 of Set 9 | makakilo city
# Processing Record 4 of Set 9 | ambon
# Processing Record 5 of Set 9 | ciudad bolivar
# Processing Record 6 of Set 9 | monroe
# Processing Record 7 of Set 9 | fairbanks
# Processing Record 8 of Set 9 | santa rosa
# Processing Record 9 of Set 9 | port-gentil
# Processing Record 10 of Set 9 | nemuro
# Processing Record 11 of Set 9 | atar
# Processing Record 12 of Set 9 | saint-augustin
# Processing Record 13 of Set 9 | kirkwall
# Processing Record 14 of Set 9 | mundo nuevo
# Processing Record 15 of Set 9 | tuatapere
# Processing Record 16 of Set 9 | boa vista
# Processing Record 17 of Set 9 | yabelo
# Processing Record 18 of Set 9 | dingle
# Processing Record 19 of Set 9 | kenai
# Processing Record 20 of Set 9 | saint george
# Processing Record 21 of Set 9 | chapais
# Processing Record 22 of Set 9 | iraan
# Processing Record 23 of Set 9 | dondo
# Processing Record 24 of Set 9 | kavieng
# Processing Record 25 of Set 9 | sapao
# City not found. Skipping...
# Processing Record 26 of Set 9 | mahudha
# Processing Record 27 of Set 9 | aranos
# Processing Record 28 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 29 of Set 9 | maloy
# Processing Record 30 of Set 9 | ahuimanu
# Processing Record 31 of Set 9 | kaili
# Processing Record 32 of Set 9 | san cristobal
# Processing Record 33 of Set 9 | gimli
# Processing Record 34 of Set 9 | fort nelson
# Processing Record 35 of Set 9 | beringovskiy
# Processing Record 36 of Set 9 | laredo
# Processing Record 37 of Set 9 | lahij
# Processing Record 38 of Set 9 | waddan
# Processing Record 39 of Set 9 | buala
# Processing Record 40 of Set 9 | koslan
# Processing Record 41 of Set 9 | acarau
# Processing Record 42 of Set 9 | colac
# Processing Record 43 of Set 9 | mocuba
# Processing Record 44 of Set 9 | agbor
# Processing Record 45 of Set 9 | marzuq
# Processing Record 46 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 9 | iglesias
# Processing Record 48 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 9 | miles city
# Processing Record 50 of Set 9 | emba
# Processing Record 1 of Set 10 | ikot ekpene
# Processing Record 2 of Set 10 | meulaboh
# Processing Record 3 of Set 10 | laguna
# Processing Record 4 of Set 10 | talnakh
# Processing Record 5 of Set 10 | ahipara
# Processing Record 6 of Set 10 | kolpashevo
# Processing Record 7 of Set 10 | ulefoss
# Processing Record 8 of Set 10 | ankazoabo
# Processing Record 9 of Set 10 | vestmannaeyjar
# Processing Record 10 of Set 10 | aswan
# Processing Record 11 of Set 10 | ghanzi
# Processing Record 12 of Set 10 | ketchenery
# City not found. Skipping...
# Processing Record 13 of Set 10 | takoradi
# Processing Record 14 of Set 10 | champerico
# Processing Record 15 of Set 10 | sibolga
# Processing Record 16 of Set 10 | qandala
# Processing Record 17 of Set 10 | vitoria da conquista
# Processing Record 18 of Set 10 | masuguru
# Processing Record 19 of Set 10 | port blair
# Processing Record 20 of Set 10 | bandarbeyla
# Processing Record 21 of Set 10 | ramapuram
# Processing Record 22 of Set 10 | spring hill
# Processing Record 23 of Set 10 | california city
# Processing Record 24 of Set 10 | bowen
# Processing Record 25 of Set 10 | waipawa
# Processing Record 26 of Set 10 | camacha
# Processing Record 27 of Set 10 | tambacounda
# Processing Record 28 of Set 10 | leskolovo
# Processing Record 29 of Set 10 | karratha
# Processing Record 30 of Set 10 | pietersburg
# Processing Record 31 of Set 10 | ferme-neuve
# Processing Record 32 of Set 10 | soure
# Processing Record 33 of Set 10 | harrison
# Processing Record 34 of Set 10 | parana
# Processing Record 35 of Set 10 | tosya
# Processing Record 36 of Set 10 | pisco
# Processing Record 37 of Set 10 | kruisfontein
# Processing Record 38 of Set 10 | polson
# Processing Record 39 of Set 10 | conil
# Processing Record 40 of Set 10 | havelock
# Processing Record 41 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 42 of Set 10 | tulsipur
# Processing Record 43 of Set 10 | garachine
# Processing Record 44 of Set 10 | marshfield
# Processing Record 45 of Set 10 | umm lajj
# Processing Record 46 of Set 10 | colon
# Processing Record 47 of Set 10 | fukue
# Processing Record 48 of Set 10 | bambanglipuro
# Processing Record 49 of Set 10 | katsuura
# Processing Record 50 of Set 10 | charters towers
# Processing Record 1 of Set 11 | darhan
# Processing Record 2 of Set 11 | qasigiannguit
# Processing Record 3 of Set 11 | mola di bari
# Processing Record 4 of Set 11 | usila
# City not found. Skipping...
# Processing Record 5 of Set 11 | dukat
# Processing Record 6 of Set 11 | kidal
# Processing Record 7 of Set 11 | zhangjiakou
# Processing Record 8 of Set 11 | kayes
# Processing Record 9 of Set 11 | nalut
# Processing Record 10 of Set 11 | dawlatabad
# Processing Record 11 of Set 11 | paso de los toros
# Processing Record 12 of Set 11 | rapid city
# Processing Record 13 of Set 11 | tiarei
# Processing Record 14 of Set 11 | praia da vitoria
# Processing Record 15 of Set 11 | howard springs
# Processing Record 16 of Set 11 | otradnoye
# Processing Record 17 of Set 11 | port macquarie
# Processing Record 18 of Set 11 | milkovo
# Processing Record 19 of Set 11 | prince rupert
# Processing Record 20 of Set 11 | bela palanka
# Processing Record 21 of Set 11 | sovetskiy
# Processing Record 22 of Set 11 | quelimane
# Processing Record 23 of Set 11 | pangnirtung
# Processing Record 24 of Set 11 | sobolevo
# Processing Record 25 of Set 11 | ancud
# Processing Record 26 of Set 11 | upernavik
# Processing Record 27 of Set 11 | berlevag
# Processing Record 28 of Set 11 | codrington
# Processing Record 29 of Set 11 | muroto
# Processing Record 30 of Set 11 | korla
# Processing Record 31 of Set 11 | aklavik
# Processing Record 32 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 33 of Set 11 | bell ville
# Processing Record 34 of Set 11 | vilhena
# Processing Record 35 of Set 11 | maldonado
# Processing Record 36 of Set 11 | north platte
# Processing Record 37 of Set 11 | shimoda
# Processing Record 38 of Set 11 | general pico
# Processing Record 39 of Set 11 | trofors
# Processing Record 40 of Set 11 | fare
# Processing Record 41 of Set 11 | udachnyy
# Processing Record 42 of Set 11 | atbasar
# Processing Record 43 of Set 11 | taoudenni
# Processing Record 44 of Set 11 | tawang
# Processing Record 45 of Set 11 | geraldton
# Processing Record 46 of Set 11 | alirajpur
# Processing Record 47 of Set 11 | anzio
# Processing Record 48 of Set 11 | tortona
# Processing Record 49 of Set 11 | jiexiu
# Processing Record 50 of Set 11 | mazamari
# Processing Record 1 of Set 12 | sakrand
# Processing Record 2 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 12 | pontes e lacerda
# Processing Record 4 of Set 12 | alofi
# Processing Record 5 of Set 12 | flinders
# Processing Record 6 of Set 12 | eenhana
# Processing Record 7 of Set 12 | henderson
# Processing Record 8 of Set 12 | moses lake
# Processing Record 9 of Set 12 | ye
# City not found. Skipping...
# Processing Record 10 of Set 12 | chernyshevskiy
# Processing Record 11 of Set 12 | barra dos coqueiros
# Processing Record 12 of Set 12 | mogadishu
# Processing Record 13 of Set 12 | puerto escondido
# Processing Record 14 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 12 | kushima
# Processing Record 16 of Set 12 | auki
# Processing Record 17 of Set 12 | los llanos de aridane
# Processing Record 18 of Set 12 | kilindoni
# Processing Record 19 of Set 12 | opuwo
# Processing Record 20 of Set 12 | kisangani
# Processing Record 21 of Set 12 | hoa binh
# Processing Record 22 of Set 12 | mahasamund
# Processing Record 23 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 12 | tucumcari
# Processing Record 25 of Set 12 | natchitoches
# Processing Record 26 of Set 12 | katherine
# Processing Record 27 of Set 12 | adelaide
# Processing Record 28 of Set 12 | barra do garcas
# Processing Record 29 of Set 12 | el copey
# Processing Record 30 of Set 12 | suluq
# Processing Record 31 of Set 12 | qostanay
# Processing Record 32 of Set 12 | dayong
# Processing Record 33 of Set 12 | mehamn
# Processing Record 34 of Set 12 | swellendam
# Processing Record 35 of Set 12 | manzhouli
# Processing Record 36 of Set 12 | gusinoye ozero
# Processing Record 37 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 38 of Set 12 | kununurra
# Processing Record 39 of Set 12 | lusambo
# Processing Record 40 of Set 12 | sept-iles
# Processing Record 41 of Set 12 | tatawin
# Processing Record 42 of Set 12 | georgiyevka
# Processing Record 43 of Set 12 | yar-sale
# Processing Record 44 of Set 12 | cumanayagua
# Processing Record 45 of Set 12 | ketchikan
# Processing Record 46 of Set 12 | usak
# Processing Record 47 of Set 12 | kabompo
# Processing Record 48 of Set 12 | viedma
# Processing Record 49 of Set 12 | azoyu
# Processing Record 50 of Set 12 | serebryansk
# Processing Record 1 of Set 13 | marbella
# Processing Record 2 of Set 13 | arman
# Processing Record 3 of Set 13 | sindor
# Processing Record 4 of Set 13 | axim
# Processing Record 5 of Set 13 | mitu
# Processing Record 6 of Set 13 | baykit
# Processing Record 7 of Set 13 | abong mbang
# Processing Record 8 of Set 13 | ostrovnoy
# Processing Record 9 of Set 13 | mandalgovi
# Processing Record 10 of Set 13 | luanda
# Processing Record 11 of Set 13 | poso
# Processing Record 12 of Set 13 | japura
# Processing Record 13 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 14 of Set 13 | hay river
# Processing Record 15 of Set 13 | santiago de cao
# Processing Record 16 of Set 13 | san ramon
# Processing Record 17 of Set 13 | qui nhon
# Processing Record 18 of Set 13 | athabasca
# Processing Record 19 of Set 13 | mahajanga
# Processing Record 20 of Set 13 | luganville
# Processing Record 21 of Set 13 | majene
# Processing Record 22 of Set 13 | bestobe
# Processing Record 23 of Set 13 | viesca
# Processing Record 24 of Set 13 | jesus carranza
# Processing Record 25 of Set 13 | dwarka
# Processing Record 26 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 27 of Set 13 | lobito
# Processing Record 28 of Set 13 | kenora
# Processing Record 29 of Set 13 | uniao da victoria
# City not found. Skipping...
# Processing Record 30 of Set 13 | alice springs
# Processing Record 31 of Set 13 | sumenep
# Processing Record 32 of Set 13 | cururupu
# Processing Record 33 of Set 13 | quatre cocos
# Processing Record 34 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 13 | suoyarvi
# Processing Record 36 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 13 | ambilobe
# Processing Record 39 of Set 13 | illkirch-graffenstaden
# Processing Record 40 of Set 13 | santa vitoria do palmar
# Processing Record 41 of Set 13 | ajdabiya
# Processing Record 42 of Set 13 | ayolas
# Processing Record 43 of Set 13 | bima
# Processing Record 44 of Set 13 | vao
# Processing Record 45 of Set 13 | okha
# Processing Record 46 of Set 13 | gallup
# Processing Record 47 of Set 13 | haines junction
# Processing Record 48 of Set 13 | verkhniy avzyan
# Processing Record 49 of Set 13 | homer
# Processing Record 50 of Set 13 | gwadar
# Processing Record 1 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 2 of Set 14 | longhua
# Processing Record 3 of Set 14 | aripuana
# Processing Record 4 of Set 14 | mount gambier
# Processing Record 5 of Set 14 | otane
# Processing Record 6 of Set 14 | portland
# Processing Record 7 of Set 14 | dali
# Processing Record 8 of Set 14 | mana
# Processing Record 9 of Set 14 | tautira
# Processing Record 10 of Set 14 | bolshaya rechka
# Processing Record 11 of Set 14 | novaya zaimka
# Processing Record 12 of Set 14 | siderno
# Processing Record 13 of Set 14 | santa isabel
# Processing Record 14 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 15 of Set 14 | carauari
# Processing Record 16 of Set 14 | marsh harbour
# Processing Record 17 of Set 14 | sauda
# Processing Record 18 of Set 14 | nizhnevartovsk
# Processing Record 19 of Set 14 | mezen
# Processing Record 20 of Set 14 | talaya
# Processing Record 21 of Set 14 | petilia policastro
# Processing Record 22 of Set 14 | tyazhinskiy
# Processing Record 23 of Set 14 | gamba
# Processing Record 24 of Set 14 | palmer
# Processing Record 25 of Set 14 | vallenar
# Processing Record 26 of Set 14 | silvania
# Processing Record 27 of Set 14 | urumqi
# Processing Record 28 of Set 14 | roviai
# Processing Record 29 of Set 14 | apache junction
# Processing Record 30 of Set 14 | monte azul paulista
# Processing Record 31 of Set 14 | sangar
# Processing Record 32 of Set 14 | muyezerskiy
# Processing Record 33 of Set 14 | tual
# Processing Record 34 of Set 14 | tongren
# Processing Record 35 of Set 14 | hami
# Processing Record 36 of Set 14 | amahai
# Processing Record 37 of Set 14 | suzu
# City not found. Skipping...
# Processing Record 38 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 39 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 14 | po
# City not found. Skipping...
# Processing Record 41 of Set 14 | havre-saint-pierre
# Processing Record 42 of Set 14 | kavaratti
# Processing Record 43 of Set 14 | sainte-savine
# Processing Record 44 of Set 14 | port huron
# Processing Record 45 of Set 14 | belinskiy
# Processing Record 46 of Set 14 | ixtapa
# Processing Record 47 of Set 14 | vershino-darasunskiy
# Processing Record 48 of Set 14 | kuznechnoye
# Processing Record 49 of Set 14 | tornio
# Processing Record 50 of Set 14 | birjand
# Processing Record 1 of Set 15 | kardla
# Processing Record 2 of Set 15 | iquique
# Processing Record 3 of Set 15 | moron
# Processing Record 4 of Set 15 | cascais
# Processing Record 5 of Set 15 | bogalusa
# Processing Record 6 of Set 15 | sakakah
# Processing Record 7 of Set 15 | isangel
# Processing Record 8 of Set 15 | avdon
# Processing Record 9 of Set 15 | mahon
# Processing Record 10 of Set 15 | tuy hoa
# Processing Record 11 of Set 15 | teluknaga
# Processing Record 12 of Set 15 | salmas
# Processing Record 13 of Set 15 | pimenta bueno
# Processing Record 14 of Set 15 | antalaha
# Processing Record 15 of Set 15 | ocos
# Processing Record 16 of Set 15 | baraki barak
# Processing Record 17 of Set 15 | olinda
# Processing Record 18 of Set 15 | shingu
# Processing Record 19 of Set 15 | vanimo
# Processing Record 20 of Set 15 | makokou
# Processing Record 21 of Set 15 | preston
# Processing Record 22 of Set 15 | mackay
# Processing Record 23 of Set 15 | podgorica
# Processing Record 24 of Set 15 | xinzhi
# Processing Record 25 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 26 of Set 15 | dudinka
# Processing Record 27 of Set 15 | cayenne
# Processing Record 28 of Set 15 | cardston
# Processing Record 29 of Set 15 | presidente epitacio
# Processing Record 30 of Set 15 | aleksandrovka
# Processing Record 31 of Set 15 | ishigaki
# Processing Record 32 of Set 15 | taketa
# Processing Record 33 of Set 15 | grand gaube
# Processing Record 34 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 15 | calabozo
# Processing Record 36 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 15 | dubrovka
# Processing Record 38 of Set 15 | hofn
# Processing Record 39 of Set 15 | omaruru
# Processing Record 40 of Set 15 | broome
# Processing Record 41 of Set 15 | krasnyy kholm
# Processing Record 42 of Set 15 | muzhi
# Processing Record 43 of Set 15 | mitsamiouli
# Processing Record 44 of Set 15 | catamarca
# Processing Record 45 of Set 15 | longido
# Processing Record 46 of Set 15 | santander
# Processing Record 47 of Set 15 | gasa
# Processing Record 48 of Set 15 | sharjah
# Processing Record 49 of Set 15 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 50 of Set 15 | kargasok
# Processing Record 1 of Set 16 | kirakira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 680

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Harbour Breton      CA  47.4833  -55.7983     31.87        79         100
# 1  Ribeira Grande      PT  38.5167  -28.7000     60.78        73          98
# 2          Anadyr      RU  64.7500  177.4833    -29.00        73         100
# 3    Punta Arenas      CL -53.1500  -70.9167     37.51        75           0
# 4          Atuona      PF  -9.8000 -139.0333     78.66        76          12
# 5     Clyde River      CA  70.4692  -68.5914    -23.57        76         100
# 6        Souillac      MU -20.5167   57.5167     82.78        65          75
# 7         Rikitea      PF -23.1203 -134.9692     79.41        72          67
# 8      Port Hardy      CA  50.6996 -127.4199     39.38        87         100
# 9         Husavik      IS  66.0449  -17.3389     27.70        77         100
#
#    Wind Speed Current Description
# 0       13.11     overcast clouds
# 1       20.00     overcast clouds
# 2       11.18     overcast clouds
# 3       11.50           clear sky
# 4       13.38          few clouds
# 5       21.85          light snow
# 6        6.91       broken clouds
# 7        5.77       broken clouds
# 8       25.32          light rain
# 9        6.15     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Harbour Breton      CA  47.4833  -55.7983     31.87        79         100
# 1  Ribeira Grande      PT  38.5167  -28.7000     60.78        73          98
# 2          Anadyr      RU  64.7500  177.4833    -29.00        73         100
# 3    Punta Arenas      CL -53.1500  -70.9167     37.51        75           0
# 4          Atuona      PF  -9.8000 -139.0333     78.66        76          12
# 5     Clyde River      CA  70.4692  -68.5914    -23.57        76         100
# 6        Souillac      MU -20.5167   57.5167     82.78        65          75
# 7         Rikitea      PF -23.1203 -134.9692     79.41        72          67
# 8      Port Hardy      CA  50.6996 -127.4199     39.38        87         100
# 9         Husavik      IS  66.0449  -17.3389     27.70        77         100
#
#    Wind Speed Current Description
# 0       13.11     overcast clouds
# 1       20.00     overcast clouds
# 2       11.18     overcast clouds
# 3       11.50           clear sky
# 4       13.38          few clouds
# 5       21.85          light snow
# 6        6.91       broken clouds
# 7        5.77       broken clouds
# 8       25.32          light rain
# 9        6.15     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_name='WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_name, index_label = "City_ID")
